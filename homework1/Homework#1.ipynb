# %% [markdown]
# # Homework \#1

# %% [markdown]
# 1. Import the Dataset

# %%
import pandas as pd

# %%
covidData = pd.read_csv("./covid19_tweets.csv")

# %% [markdown]
# 2. Shape of the data set

# %%
covidData.shape
# Out:
# (179108, 13)

# %% [markdown]
# 3. 15 first rows of the dataset

# %%
covidData.head(15)
# Out:
#                              user_name  \
# 0                               ᏉᎥ☻լꂅϮ
# 1                        Tom Basile 🇺🇸
# 2                      Time4fisticuffs
# 3                          ethel mertz
# 4                             DIPR-J&K
# 5                     🎹 Franz Schubert
# 6                         hr bartender
# 7                       Derbyshire LPC
# 8                    Prathamesh Bendre
# 9    Member of Christ 🇨🇳🇺🇸🇮🇳🇮🇩🇧🇷🇳🇬🇧🇩🇷🇺
# 10              Voice Of CBSE Students
# 11                         Creativegms
# 12                          SEXXYLYPPS
# 13  Africa Youth Advisory Board on DRR
# 14                      DailyaddaaNews
#
#                                         user_location  \
# 0                                          astroworld
# 1                                        New York, NY
# 2                                    Pewee Valley, KY
# 3                                Stuck in the Middle
# 4                                   Jammu and Kashmir
# ...

# %% [markdown]
# 4. day of the week

# %%
covidData["date"] = pd.to_datetime(covidData.date)
covidData["day_of_the_week"]= covidData.date.dt.day_name()

# %% [markdown]
# 5. Explain the day of the week

# %%
# day of the week
# we convert the date column into a date time object with pandas method "to_datetime"
# then we create a day_of_the_week, we turn the datetime into the day of the week the day name method
